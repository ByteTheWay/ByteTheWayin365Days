# %%
a = [1, 2, 3, 4, 5]
b = []

for x in a:
    if x%2==0:
        b.append("even")
    else:
        b.append("odd")

print(b)
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']

# %%
a = [1, 2, 3, 4, 5]

b = ['even' if i%2==0 else 'odd' for i in a]
print(b)
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']
