# %%
import math
math.pi
print(math.pi)

math.pi += 2022
print(math.pi)
# Out:
# 3.141592653589793
# 2025.14159265359

# %%
def pi():
    return 3.141592653589793
print("pi = ", pi())

radius = 7
area = pi()*(radius**2)
print("\nArea = ", area)
print("pi = ", pi())
# Out:
# pi =  3.141592653589793
#
# Area =  153.93804002589985
# pi =  3.141592653589793

# %% [markdown]
# Python never really has any constant, they could be changed whatsoever. Speaking of which, how do we make them as if they are a constant as well as any programming language? I mean, a constant that could never be changed!
#
# Code 1 depicts a pi constant from the "math" module that has changed. Whereas, pi constant in Code 2 is fixed. Hence, we also can make any constant as if they could never be changed. In Python, any constant from modules is a changeable rule that we can disobey for a certain reason.
